# %% [markdown]
# <a href="https://colab.research.google.com/github/ds-20195/notebooks/blob/main/Notebook0.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Welcome to "Data and the State"!
# **DATA 20195/30195**
#
# This is the warmup notebook for Spring 2026. If you have no prior coding experience, or are new to the Python language or Google Colab, we highly encourage you to go through this notebook on your own and bring questions to our first lab session this Friday, March 27th.

# %% [markdown]
# This notebook covers how to:
# * navigate python notebooks (like this one);
# * write and evaluate basic expressions in Python;
# * call functions to use code other people have written;
# * and break down Python code into smaller parts to understand it.

# %% [markdown]
# ## Acknowledgement
#
# This notebook is adapted from the following sources.
#
# - ``gentle-intro`` developed for PUBPOL 2130 at Cornell University.
# - ``Lab 1`` developed for [Data 8 (Foundations of Data Science)](https://github.com/data-8/materials-sp26/blob/main/lab/lab01/lab01.ipynb) at UC Berkeley, Licensed under [CC BY-NC 4.0](https://creativecommons.org/licenses/by-nc/4.0/).

# %% [markdown]
# <br/><br/>
#
# <hr style="border: 1px solid #fdb515;" />
#
# # Part 1: Google Colab and python notebooks
# Google Colab runs in a web browser but executes the code on Google's cloud servers, offering free access to computational resources, including GPUs and TPUs, without requiring any local setup or installation.
#
# If you look at the top of the page you see the title "Notebook0.ipynb", the '.ipynb' file type stands for "Interactive Python Notebook," and is different from a basic '.py' python code file because it contains both text, code, and code output.

# %% [markdown]
# ---
#
# ## 1.1. Text cells
# In a notebook, each rectangle containing text or code is called a *cell*.
#
# **Text cells** (like this one) can be edited by double-clicking on them. They're written in a simple format called [Markdown](https://www.markdownguide.org/basic-syntax/) to add formatting and section headings.  You don't need to learn Markdown, but you might want to.
#
# After you edit a text cell, click the "Close" button at the top middle of the cell or hold down `shift` + `return` to confirm any changes.

# %% [markdown]
# ---
#
# ## 1.2. Code cells
# **Code cells** contain code in the Python language. Running a code cell will execute all of the code it contains.
#
# To run the code in a code cell, first click on that cell to activate it.  It'll be highlighted with a little green or blue rectangle.  Next, either press ▶ or hold down `shift` + `return`.
#
# Try running the cell directly below:

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Congratulations!** You're officially coding in python!

# %% [markdown]
# As a note, we are currently working in a jupyter (colab) notebook environment, and in these environments, last item in the cell is generally printed as a matter of convenience.

# %%
"This is not printed"

"This is not printed either"

"This will be printed since it's the last item in the cell"
# Out:
# "This will be printed since it's the last item in the cell"

# %% [markdown]
# To display code from other lines in the cell, we need the `print` statment:

# %%
print("This is printed")

"This is not printed"

"This will still be printed since it's the last item in the cell"
# Out:
# This is printed
# "This will still be printed since it's the last item in the cell"

# %% [markdown]
# ---
#
# ## 1.3. Writing Python notebooks in Google Colab
# You can use notebooks for your own projects or documents.  When you make your own notebook, you'll need to create your own cells for text and code.
#
#
# **Add Cells**
#
# To add a cell, click either the `+Code` or `+Text` button in the top menu bar, or hover over the bottom of a cell and the same buttons will appear. You can also use keyboard shortcuts when you have a cell selected (but not being edited) and press `a` (adds a code cell **a**bove the current cell) or `b` (adds a code cell **b**elow the current cell) to add cells.
#
# **Delete Cells**
#
# To delete a cell you have selected, you can click on the trash can symbol on the right hand side menu bar at the top of the cell. To delete multiple consecutive cells all at once: select the first cell you want to delete, hold down `shift`, select the last cell you want to delete, then press the trash can button.
#
# **Recover Cells**
#
# Accidentally delete something important? No stress -- go to the top menu bar and under the `Edit` section the top option is to undo the delete.
#
# **Text Cell Types**
#
# Text cells can either be normal text or section headings. Note that all text or code cells that fall between section heading 1 and section heading 2 are automatically assigned to section 1, and will be visible when that section is collapsed (see the arrow to the left of the heading).
#
# **Cell Reordering**
#
# If you want to move a cell around, you can either select it, right click to copy, then paste it in the desired spot OR you can use the up and down errors on the cell's right hand side tool bar to move it up and down through the notebook. You can use the same multiple cell selection technique mentioned above in the delete cells part to move multiple cells at a time.

# %% [markdown]
# ---
#
# ## 1.4. The Kernel
# The code you run in a Google Colab notebook is not executed by your own computer, instead, Google provides access to a virtual kernel. You can think of the kernel as the computational engine that executes your code and stores the information from the code it runs into its memory.
#
# When you run a code cell, at the left of the cell you will see the indicator moving to show that cell is being processed by the kernel. Once it finishes processing, a green check mark will show up on the left side of the cell. If a cell is taking too long, or you realize you have an error you want to fix mid-run, you can stop the execution of the cell by pressing the indicator (the square shape indicates stop or pause).
#
#
# You may run into problems where your kernel is stuck for an excessive amount of time, your notebook is very slow and unresponsive, or your kernel loses its connection. If this happens, click on the `Runtime` button in the top menu bar and then `Restart session`. Note that this will wipe the kernel's memory, so you will have to re-run cells above the one that caused the crash.

# %% [markdown]
# **Note:** In the toolbar, there is the option to click ` Run All`, which will run all the code cells in this notebook in order. However, the notebook stops running code cells if it hits an error, which we will discuss soon.

# %% [markdown]
# ---
#
# # Part 2. Coding Basics

# %% [markdown]
# ## 2.1 Basic Data Types in Python
#
# Python handles different types of data in different ways. We will go through the most common ones that you will likely deal with in this course. You can examine the type of an expression in Python using ``type``, function, and, for now, we will be working with the following types:
#
# - an integer (int), which is a whole number (negative or positive),
# - a floating point number (float), which is a number represented in decimal,
# - a Boolean (bool), which is a variable that can store only two values: True, or False.
# - a string (str), which is a list of characters -- it can be a word or a whole sentence,

# %%
# int for integer
type(3)
# Out:
# int

# %%
#float for numbers with decimal values
type(2.44)
# Out:
# float

# %% [markdown]
# ## 2.2 Numbers (ints and floats)
#
# At its most basic, Python may be used similarly like calculator. Run the following cell to see how it represents the expression ``3.1400``.

# %%
3.1400
# Out:
# 3.14

# %% [markdown]
# By default, Python will only display the output of the last line. Use ``print`` if you want to display expressions from other lines.

# %%
print(3)
4
5
# Out:
# 3
# 5

# %% [markdown]
# Just like a calculator, you can perform arithmetic between numbers.

# %%
print(1 + 2)
print(3.14 - 1.05)
print(4 * 2)
print(10 / 5)
# Out:
# 3
# 2.09
# 8
# 2.0

# %% [markdown]
# One operator that differs from traditional math notation is ``**``, which represents exponentiation. For example, ``2**3`` stands for $2^3$ and evaluates to 8.

# %%
2**3
# Out:
# 8

# %% [markdown]
# ## 2.3 Annotating your Code with Comments
#
# Python is a pretty readable computer language, meaning that someone with computer science experience outside of python should be able to read Python code and generally understand what is going on. However, the code itself doesn't always tell the full story. We use comments to explain the intent and thought behind the code used.
#
# You comment on a specific line or section of code by going to the line above it (or by adding them to the end of that line of code), typing `#`, then writing out your explanation. Note that Python usually visualizes commented text in a different color from the code, and this text is **ignored by the computer** when the code is ran.
#
# Below is an example of how comments are used to to add context to lines of code.

# %%
# This is the same cell as earlier, but now with comments!


print(1 + 2) # This should print 3
print(3.14 - 1.05) # This should print 2.09
print(4 * 2) # This should print 8 (an integer)
print(10 / 5) # This should print 2.0 (a float since division always returns a float)
# Out:
# 3
# 2.09
# 8
# 2.0

# %% [markdown]
# ## 2.4 Variables
#
# At this point, if we want to perform different operations on the same expression, we have to copy-paste the expression for each operation.

# %%
print(5 - 4)
print((5 - 4)/4)
print(((5 - 4) / 4) * 100)
# Out:
# 1
# 0.25
# 25.0

# %% [markdown]
# This becomes troublesome to manage very quickly. Luckily, in Python, we have **variables** that help make this easier. Variables are names that can be assigned to expressions via *assignment statements*. To assign a variable to an expression, put the variable name on the left side of an ``=`` sign and an expression on the right.

# %%
ten = 3 * 2 + 4

# %% [markdown]
# When you run that cell, Python first computes the value of the expression on the right-hand side, `3 * 2 + 4`, which is the number 10.  Then it assigns that value to the name `ten`.  At that point, the code in the cell is done running.
#
# After you run that cell, the value 10 is bound to the name `ten`:

# %%
ten
# Out:
# 10

# %% [markdown]
# Now, you can perform any operation on the variable ``ten`` as you would with the expression ``3 * 2 + 4``.

# %%
ten + 1
# Out:
# 11

# %%
ten / 2
# Out:
# 5.0

# %% [markdown]
# Note that, as you could have assigned any other expression to the variable name ``ten``, you can easily override its meaning if you perform another assignment in later operations.

# %%
ten = 3 * 2 + 4
print(ten)
ten = 3 * 2 + 5
print(ten)
# Out:
# 10
# 11

# %% [markdown]
# This is often undesirable as you can lose track of what the variable name is actually assigned to. Therefore, you should avoid assigning the same variable name to different expressions, unless the override is intentional.
#
# Here are some rules and conventions when it comes to creating variable names.
#
#
# 1. You cannot have any space in a variable name.
# ```python
# number ten = 3 * 2 + 4
# ```
#
# 2. If you want to use multiple words for a variable name, connect them via an underscore ``_``. (This is called [snake_case](https://en.wikipedia.org/wiki/Snake_case))
# ```python
# number_ten = 3 * 2 + 4
# ```
#
# 3. Sometimes you will also see multi-word variable names in the format of [camelCase](https://en.wikipedia.org/wiki/Camel_case). Try to not use this in your Python code, however, as it goes against usual standards for variable names.
# ```python
# numberTen = 3 * 2 + 4
# ```
#
# 4. You cannot start a variable name with a number (but you can end with one).
#
# ```python
# 10number = 3 * 2 + 4 # This will produce an error
#
# number10 = 3 * 2 + 4 # This is fine
# ```
#
# 5. Try to make your variable names descriptive so that you do not forget what the value stored in that variable is supposed to represent!
#
# ```python
# x = 5 # Not a great name
#
# number_of_beans_in_jar = 5 # Better since now I won't mix this up with other variables
# ```

# %% [markdown]
# ### Try it!
#
# In the following code cell,
#
# 1. Make a variable named `observed` and assign it the value `5`. Then print that variable.
# 2. Make a variable named `expected` and assign it the value `4`. Then print that variable.
# 3. Compute the _proportional deviation from the expected value_ according to the formula $\frac{observed - expected}{expected}$ and store this value in a variable named `relative_error`. Then print that variable.
# 4. Compute the _percent deviation from the expected value_ according to the formula $100 * \frac{observed - expected}{expected}$ and store this value in a variable named `percent_deviation`. Then print that variable.

# %%
observed = 2 + 3
print(observed)
# Out:
# 5

# %%
expected = 2+2
print(expected)
# Out:
# 4

# %%
relative_error = (observed - expected)/expected
print(relative_error)
# Out:
# 0.25

# %%
percent_deviation = 100*(observed - expected)/expected
print(percent_deviation)
# Out:
# 25.0

# %% [markdown]
# ## 2.5 Strings
#
# A string stores text or a sequence of characters, and can be wrapped in single or double quotation marks.

# %%
"Data"

# %%
'Data'

# %% [markdown]
# Just like numbers, strings can be added in Python. The result is a concatenation of the added components.

# %%
"Data" + "and" + "the" + "State"

# %% [markdown]
# Note that spaces inside of concatenated strings are also preserved.

# %%
"Data" + " and" + " the" + " State"

# %% [markdown]
# But subtraction would not work. For example, if I want to remove the ``a`` in ``Data``, this would not work (why?):

# %%
"Data" - "a"

# %% [markdown]
# To achieve this, we use a special operation ``.replace("a", "")``.

# %%
"Data".replace("a", "")

# %% [markdown]
# In natural language, we are telling Python to replace all the ``"a"`` in ``"Data"`` by ``""``, an empty string. There are many other operations you can perform on strings, many will be very helpful in the future. Play around with the following expressions.

# %% [markdown]
# ### Try it!
#
# In the following code cell do the following:
# - Convert `my_string` into all Upper-Case using the `upper()` method and print it.
# - Convert `my_string` into all lower-case using the `lower()` method and print it.
# - Remove the prefix string "Data " from the string using the `remove_prefix(<prefix here>)` method and print it.
# - Try printing out `my_string.strip("Date ")`. What happens?

# %%
my_string = "DatA And tHe STAte"

print(my_string.title()) # This will print the string in title case, where the first letter of each word is capitalized and the rest are lowercase.

print(my_string.upper())
print(my_string.lower())
print(my_string.removeprefix("Data "))
print(my_string.strip("Date ")) # This one removes leading/trailing characters present in "Date " from the string. Since 'D' is the first char and 'e' is not, it removes 'D' and 'a'.
# Out:
# Data And The State
# DATA AND THE STATE
# data and the state
# DatA And tHe STAte
# A And tHe STA

# %% [markdown]
# ## 2.6 Booleans
#
# People sometimes talk about a computer as "a bunch of ones and zeros", so it is natural for any programming language to have a data type specifically for that. The Boolean data type represents only two values ``True`` (``1``) or ``False`` (``0``). Note that capitalization matters here.

# %%
type(True)
# Out:
# bool

# %% [markdown]
# Boolean values allows for lots of logical expressions and operations. The simplest of them are ``>``, ``>=``, ``==``, ``<``, and ``<=``. You can use these to compare different values.
#
# > ⚠️ WARNING ⚠️ the `==` operator is used to check for equality, and the `=` operator is used for variable assignment. Don't mix them up!!

# %%
print(2 < 3)
print(5 > 7)
# Out:
# True
# False

# %% [markdown]
# You can also compare outputs of math operations. Use parentheses to specify order of operations. In the following expression, Python first computes ``5/2`` and ``10/4``, then assesses whether the results are equal.

# %%
(5 / 2) == (10 / 4)
# Out:
# True

# %% [markdown]
# Another common operation is ``and``, ``or``, and ``not``. For example, ``and`` evaluates to ``True`` if both expressions it assesses are ``True`` or evaluate to ``True``.

# %%
# "and" evaluates to True if both expressions are True
print("and ============================")
print(True and True)
print(True and False)
print(False and True)
print(False and False)
print("")

# "or" evaluates to True if at least one of the expressions is True
print("or ============================")
print(True or True)
print(True or False)
print(False or True)
print(False or False)
print("")

# "not" evaluates to True if the expression is False
print("not ============================")
print(not True)
print(not False)
# Out:
# and ============================
# True
# False
# False
# False
#
# or ============================
# True
# True
# True
# False
#
# not ============================
# False
# True

# %% [markdown]
# ### Try it!
#
# Let's combine what we have learned about numbers and Booleans. In the following code cell do the following
# - Construct an expression that determines if $(2 + 3^2) / 2$ is greater than $5$. Store the output of this expression in the variable `statement_1` and print it.
# - Construct an expression that determines if $10 / 5$ is equal to $6 / 3$. Store the output of this expression in the variable `statement_2` and print it.
# - Construct a logical expression that determines if both statements are `True` and print out that expression.

# %%
statement_1 = (2 + 3**2)/2 > 5
print(statement_1)
# Out:
# True

# %%
statement_2 = 10/5 == 6/3
print(statement_2)
# Out:
# True

# %%
statement_1 and statement_2
# Out:
# True

# %% [markdown]
# ## 2.7 Bugs and Error Messages
# Python is a language, and like natural human languages, it has rules.  It differs from natural language in two important ways:
# 1. The rules are *simple*.  You can learn most of them in a few weeks and gain reasonable proficiency with the language in a quarter.
# 2. The rules are *rigid*.  If you're proficient in a natural language, you can understand a non-proficient speaker, glossing over small mistakes.  A computer running Python code is not smart enough to do that.
#
# As you learn to write code, you'll make mistakes. These mistakes are called [bugs](https://spectrum.ieee.org/did-you-know-edison-coined-the-term-bug) or errors.   When you run a code cell that has errors, Python will sometimes produce error messages to tell you what you did wrong.
#
# Errors are okay; even experienced programmers make many errors.  When you make an error, you just have to find the source of the problem, fix it, and move on.
#
# We have made an error in the next cell.  Run it and see what happens.

# %%
print("This line is missing something.")
# Out:
# This line is missing something.

# %% [markdown]
# The small arrow in the error message is the system's best guess as to where the error is caused. The last line of the error output attempts to tell you what went wrong.  The *syntax* of a language is its structure, and this `SyntaxError` tells you that you have created an illegal structure.
#
# The error here is that we do not have a closing parenthesis `)`.
#
# This is a very common error in coding -- make sure to always close your parenthesis `()`, brackets `[]`, and quotation marks `''` `""`!

# %%
print("This line is missing something.")
# Out:
# This line is missing something.

# %% [markdown]
# See the cell below for another error example.

# %%
# We are trying to create a dictionary of employee names and their ages, but we made a typo in the
# first line.
#
# We will be talking about dictionaries in more detail in the cells below! This is here for the
# sake of demonstrating how to read error messages and debug code.
employees = {
    "pam" 30,   # This line is missing a colon between the key "pam" and the value 30, but the error message will say something else
    "jim": 28
}

# %% [markdown]
# Note that the error message points again to where it suspects the error to be located and we are told this is invalid syntax. However, what is missing is a `:`, not a comma as suggested. We will discuss this particular expression later in the notebook.

# %%
employees = {
    "pam": 30,
    "jim": 28
}

# %% [markdown]
# Error messages are not perfect and will often require further investigation to fix the issue, but they do provide a good place to start.
#
# You might notice the `Explain error` button that appears below the error code blocks, this button opens up Google's AI, Gemini, to help explain the error further. AI can be very helpful in fixing bugs, but we encourage you to investigate errors yourself first, and make sure you understand the correction suggested by AI if you decide to use it. Finding and fixing bugs is the **BEST** way to truly learn the syntax of a programming language!

# %% [markdown]
# ## 2.8 Lists
#
# In data science, we rarely work with a single number/datum. Instead, we work with a collection of data. A list in Python is a collection of items created using square brackets ``[]``.

# %%
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
["Data Science", "Public Policy", "Economics"]
# Out:
# ['Data Science', 'Public Policy', 'Economics']

# %% [markdown]
# You can assess the length of a list using the ``len`` function.

# %%
len(["Data Science", "Public Policy", "Economics"])
# Out:
# 3

# %% [markdown]
# Adding 2 lists concatenates them.

# %%
["Data Science", "Public Policy", "Economics"] + ["Computer Science"]
# Out:
# ['Data Science', 'Public Policy', 'Economics', 'Computer Science']

# %% [markdown]
# ### List Indexing
#
# An important list operation is **indexing**. This allows you to access specific elements of the list. You can index into a list using another set of square brackets wrapped around the index you would like to access.
#
# **Note** The Python index starts at ``0``, so the following expression gives you the first element of the list.

# %%
my_courses_list = ["Data Science", "Public Policy", "Economics", "Computer Science", "Statistics"]

# %%
my_courses_list[0] # Try changing this to see what you get!
# Out:
# 'Data Science'

# %% [markdown]
# We will see an error if the index passed in is beyond the number of elements in the list.

# %%
my_courses_list[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_627/1367698925.py in <cell line: 0>()
# ----> 1 my_courses_list[10]
#
# IndexError: list index out of range

# %% [markdown]
# You can also obtain several elements of the list altogether using the ``:`` operator. For example, if we would like to extract a sublist (a.k.a. a _slice_ of the list) containing those elements lying between index $i$ and index $j$ (including $i$ and $j$), we would write something like
#
# ```
# [our list][i:j+1]
# ```
#
# Notice the position after the colons is exclusive, so to get up to the $j$-th element, we need to add 1 to the index.

# %%
my_courses_list[1:3]
# Out:
# ['Public Policy', 'Economics']

# %% [markdown]
# If $i=0$ or $j=$ last index of the list, we can ignore them for simplicity.

# %%
# These two lines of code are equivalent!
# The first one explicitly says to start at index 0, while the second one just leaves it blank,
# which Python understands to mean the same thing.
print(my_courses_list[0:3])
print(my_courses_list[:3])
# Out:
# ['Data Science', 'Public Policy', 'Economics']
# ['Data Science', 'Public Policy', 'Economics']

# %%
print(my_courses_list[2:])
print(my_courses_list[2:5])
# Out:
# ['Economics', 'Computer Science', 'Statistics']
# ['Economics', 'Computer Science', 'Statistics']

# %% [markdown]
# **Note** In Python, strings are essentially treated as lists characters, so many list operations (like indexing, slicing, and concatenation) work for both

# %%
my_string = "Data"
print(len(my_string))
print(my_string + " and" + " the" + " State")
print(my_string[:3])
print("Data and the State".split(" "))  # what does this operation do?
# Out:
# 4
# Data and the State
# Dat
# ['Data', 'and', 'the', 'State']

# %% [markdown]
# ## 2.9 Dictionaries
#
# A physical dictionary maps a *word* to its *definition*. A **dictionary** in Python does exactly the same thing: It maps a ``key`` to its ``value``. Take a look at the following dictionary.

# %%
{"apple": "red", "banana": "yellow", "grape": "purple"}
# Out:
# {'apple': 'red', 'banana': 'yellow', 'grape': 'purple'}

# %% [markdown]
# Notice key components of a dictionary:
#
# - It is entirely wrapped between a pair of curly brackets ``{}``.
# - Each ``key`` and ``value`` pair is connected via a colon ``:``.
# - In this case, ``"apple"``, ``"banana"``, and ``"grape"`` are keys, and ``"red"``, ``"yellow"``, ``"purple"`` are values.
#
# Keys and values don't need to be just strings.

# %%
{"apple": [1, 2, 3], "banana": [4, 5, 6], "grape": [7, 8, 9]}
# Out:
# {'apple': [1, 2, 3], 'banana': [4, 5, 6], 'grape': [7, 8, 9]}

# %%
{1: "one", 2: "two", 3: "three"}

# %%
{1: 1, 2: 4, 3: 9}

# %% [markdown]
# To query a dictionary, we can input a key wrapped between square brackets ``[]``, similar to indexing into a list.

# %%
{"apple": "red", "banana": "yellow", "grape": "purple"}["grape"]

# %% [markdown]
# We can also get all of the keys or values to a dictionary using ``.keys()`` and ``.values()``

# %%
{"apple": "red", "banana": "yellow", "grape": "purple"}.keys()
# Out:
# dict_keys(['apple', 'banana', 'grape'])

# %%
{"apple": "red", "banana": "yellow", "grape": "purple"}.values()
# Out:
# dict_values(['red', 'yellow', 'purple'])

# %% [markdown]
# ## 2.10 Functions
#
# Take a moment and think back to your math basics -- what makes a **function**?
#
# *   input(s)
# *   output(s)
# *  some internal mechanism that maps input(s) to output(s)
#
# In Python coding, functions take in input(s) and produce output(s). We have actually already used many functions in the code cells above:

# %%
print('Print is a native python function!')

# %%
type(2)
# Out:
# int

# %% [markdown]
# Note that the **inputs** taken in by these functions are the string and the number, respectively (what about the outputs?).
#
# ### Function Inputs
#
# Some functions take in multiple inputs (often referred to as "arguments" or "parameters"). When the functions are defined in Python, each argument is given a name (similar to variable names). We can pass arguments into the function using their names.
#
# For example, the ``round`` function takes in 2 arguments:
#
# - ``number`` the number to be rounded;
# - ``ndigits`` the number of decimal places to round to.

# %%
round(number=32.55434, ndigits=2)
# Out:
# 32.55

# %% [markdown]
# For simplicity, if you know the designated order of the arguments (see [documentation](https://docs.python.org/3/library/functions.html#round)), you can input the values in that order, **without** writing out the names of the arguments.

# %%
round(32.55434, 2)
# Out:
# 32.55

# %% [markdown]
# Now notice the error raised if we do not pass in arguments in the designated order.

# %%
round(2, 32.55434)

# %% [markdown]
# Also, some functions may allow you to give multiple inputs, but don't require all to be specified. The function will run using a default value for the input that isn't specified. Here we see that the ``round`` function uses 0 decimal places as its default value.

# %%
round(32.55434)
# Out:
# 33

# %% [markdown]
# ### Native functions, packages, and self-defined functions
#
# The three examples of functions above are all native, built-in Python functions, meaning they are embedded into the language. Python documentation provides a [complete list of native functions](https://docs.python.org/3/library/functions.html).
#
# Though there are many native functions, a coder limited to just native functions will quickly become stuck depending on what they are trying to do. For our course, we will rely heavily on downloading `packages` that come with special functions that allow us to analyze and visualize **geospatial data**. You will see many examples of this in future labs, but one thing to keep in mind now is that when you want to use a function from a package you have to include the name (or nickname) of that package before the name of the function.

# %%
# The 'import' keyword tells Python to look and see if the package is installed already, and,
# if it is, it adds that package to the kernel so that we can use functions that are defined in
# that package
#
# The 'as' keyword allows us to give the package a nickname, which is useful since some packages
# have long names.
import matplotlib.pyplot as plt

# runs the 'plot' function, which comes in the matplotlib.pyplot package
# note that we had to include 'plt' to direct the computer to look for the
# function in the matplotlib.pyplot package
plt.plot([0, 1], [0, 10])

# %% [markdown]
# The nicknames we give are not random, but are well established conventions in the coding world.
#
# Here are some examples:

# %%
import numpy as np

import pandas as pd

# %% [markdown]
# In some cases a function might not exist that does **exactly** what you need, and in that case you are able to define your own function, as follows:

# %%
def calculate_property_tax(market_value, mill_rate):
    # the portion of the total value you taxed on
    assessment_ratio = 0.80
    assessed_value = market_value * assessment_ratio

    # property tax uses the Mill rate, which is how many $ of taxes you owe per $1000 of assessed value
    tax_bill = (assessed_value / 1000) * mill_rate

    return tax_bill

# %% [markdown]
# Note the following from the function definition above:
#
#
# *  `calculate_property_tax` is the name of the function (like 'print' is the name of the print() function)
# *   `market_value` and `mill_rate` are the input values of the function
#     * the input values are used throughout the function in the calculations
# * all lines within the function are indented
# * the function output is `tax_bill` as designated by the `return` line
#
#
# Now, let's *call* our function by its name and designate the inputs for a $500,000 house with a mill rate of 15.

# %%
calculate_property_tax(500000, 15)
# Out:
# 6000.0

# %% [markdown]
# ### Try it!
#
# In the following code cell, let's make a function that compute the _absolute percentage error from the expected value_ according to the formula $100 * \frac{|observed - expected|}{expected}$. You will need to make use of the built-in `abs` function to do this!

# %%
def absolute_percentage_error(observed_value, expected_value):
    numerator = abs(observed_value - expected_value) # Use abs() built-in function
    denominator = expected_value
    return 100 * numerator / denominator

# %% [markdown]
# ### Methods
#
# Besides standalone functions, some data types are attached to their own custom functions (referrred to as **methods**). To access a method, we use the ``.method()`` syntax appended to the expression. You have already seen some examples of `methods` above, here they are again:

# %%
"Data".replace("a", "")
# Out:
# 'Dt'

# %%
print("Data and the State".upper())
print("Data and the State".lower())
print("Data and the State".strip("Date "))  # this one is tricky
# Out:
# DATA AND THE STATE
# data and the state
# nd the S

# %% [markdown]
# ### Nesting
# In some cases we need to run multiple functions or operations, stacked *logically* on top of eachother.
# The most basic example is an arithmetic operation within a function call.

# %%
# first the subtraction is calculated, then the function is applied
abs(23-45)
# Out:
# 22

# %% [markdown]
# Nesting moves from the inside to the outside.
# Note where the `2` is placed differently in these two opposite orderings -- it is important to keep track of **which** parenthesis capture **what**.

# %%
round(abs(23-45.34),2)
# Out:
# 22.34

# %%
abs(round(23-45.34,2))
# Out:
# 22.34

# %%
abs(round(23-45.34),2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_627/2322984832.py in <cell line: 0>()
# ----> 1 abs(round(23-45.34),2)
#
# TypeError: abs() takes exactly one argument (2 given)

# %% [markdown]
# Note below how the order can sometimes change the outcome!

# %%
int(round(3.7))
# Out:
# 4

# %%
round(int(3.7))
# Out:
# 3

# %% [markdown]
# ## 2.12 Advanced Operations
#
# Python is a reasonably flexible language, so sometimes you will encounter operations that go beyond what we have discussed above. Here are some other operations you can perform to code more efficiently.

# %% [markdown]
# ### Formatted String
#
# Consider a numerical variable ``score``. We want to print out the sentence ``"The score is x."``, with ``x`` replaced by the score. We can do this by first converting the number to a string using an operation called ``str()``, then use concatenation.

# %%
score = 75
score_str = str(score)
sentence = "The score is " + score_str + "."
print(sentence)
# Out:
# The score is 75.

# %% [markdown]
# Or we can do this in one line.

# %%
print("The score is " + str(score) + ".")
# Out:
# The score is 75.

# %% [markdown]
# However, this is not very efficient. A better way to do this is to use **formatted strings** (f-strings).

# %%
print(f"The score is {score}.")
# Out:
# The score is 75.

# %% [markdown]
# We place the letter f in front of the starting quotation mark, and put the variable, wrapped in curly brackets, in the part of the sentence we would like it to replace. We can also place an expression in the curly brackets, and Python will execute the expression before adding it to the string.

# %%
print(f"The score is greater than 70: {score > 70}")
# Out:
# The score is greater than 70: True

# %% [markdown]
# ### Conditional Statments
#
# Consider a variable ``score``. We want to print out the corresponding letter grade. Currently, this is the best we can do:

# %%
score = 75

print(f"The grade is A: {score >= 90}")
print(f"The grade is B: {score >= 80}")
print(f"The grade is C: {score >= 70}")
print(f"The grade is F: {score < 70}")
# Out:
# The grade is A: False
# The grade is B: False
# The grade is C: True
# The grade is F: False

# %% [markdown]
# A more simple way is to use **if-else** statements.

# %%
if score >= 90:
    print("The grade is A.")
elif score >= 80:
    print("The grade is B.")
elif score >= 70:
    print("The grade is C.")
else:
    print("The grade is F.")
# Out:
# The grade is C.

# %% [markdown]
# In natural language, the code does the following.
#
# - First assess if the ``score`` is at least 90, if so, print ``"The grade is A"``.
# - If the first assessment is not true, assess whether ``score`` is at least 80. If so, print ``"The grade is B"``.
# - If the first and second assessments are not true, assess whether ``score`` is at least 70. If so, print ``"The grade is C"``.
# - If none of the above is true, print ``"The grade is F"``.
#
# Additionally, note the **indentation**: Every time we have a conditional statement, we need to indent the code we would like Python to execute if the statement is True.

# %% [markdown]
# ### For-Loops
#
# Consider a list of numbers called ``numbers``. If we would like to print out each element of the list, raised to the power of 3. We can do the following.

# %%
numbers = [1.21, 10.75, 3.45, 5.99]

print(numbers[0] ** 3)
print(numbers[1] ** 3)
print(numbers[2] ** 3)
print(numbers[3] ** 3)
# Out:
# 1.771561
# 1242.296875
# 41.06362500000001
# 214.92179900000002

# %% [markdown]
# This is inefficient (consider if the list has 1000 numbers). Instead, Python has a special operation called ``for-loop`` that handles repetitive operations like this.

# %%
for x in numbers:
    print(x**3)
# Out:
# 1.771561
# 1242.296875
# 41.06362500000001
# 214.92179900000002

# %% [markdown]
# Note we achieve the exact same result, but in 2 lines instead of 4. In natural language, the code does the following.
#
# - Look at the list ``numbers``.
# - Loop 1: Assign the variable name ``x`` to the first element of ``numbers`` (equavalent to ``x=numbers[0]``), then perform the specified operation (i.e. ``print(x**3)``).
# - Loop 2: Assign the variable name ``x`` to the second element of ``numbers`` (equavalent to ``x=numbers[1]``), then perform the specified operation (i.e. ``print(x**3)``).
# - Loop 3: Assign the variable name ``x`` to the third element of ``numbers`` (equavalent to ``x=numbers[2]``), then perform the specified operation (i.e. ``print(x**3)``).
# - Loop 4: Assign the variable name ``x`` to the third element of ``numbers`` (equavalent to ``x=numbers[3]``), then perform the specified operation (i.e. ``print(x**3)``).
#
# Notice every last part of the sentence in the last four bullets are exactly the same. Through assigning the same variable to different expressions, a for-loop handles the repetitive task of printing out each number, raised to the power of three.
#
# **Note** Here ``x`` is simply a choice of a placeholder, as we can use any other variable name.

# %%
for this_is_a_very_long_variable_name  in numbers:
    print(this_is_a_very_long_variable_name**3)
# Out:
# 1.771561
# 1242.296875
# 41.06362500000001
# 214.92179900000002

# %%
for _ in numbers:
    print(_**3)
# Out:
# 1.771561
# 1242.296875
# 41.06362500000001
# 214.92179900000002

# %% [markdown]
# ### Try it!
#
# Create a function that loops through two lists of numbers and prints out the _absolute percentage error from the expected value_ for each pair. You may want to use one of your earlier functions here

# %%
def absolute_percentage_error_for_lists(observed_values_list, expected_values_list):
    results = []
    for i in range(len(observed_values_list)):
        results.append(absolute_percentage_error(observed_values_list[i], expected_values_list[i]))
    return results

# You don't need to touch the below code. This is just here to help you test your function once you finish it!
list_1 = [1, 2, 3]
list_2 = [1.1, 1.9, 3.2]
print(absolute_percentage_error_for_lists(list_1, list_2))
# Out:
# [9.090909090909099, 5.263157894736847, 6.250000000000005]

# %% [markdown]
# # Well done 🎊🎊🎊! You are on your way to becoming a proficient Python programmer. Please bring any questions to our first lab session. Excited to discuss with you all there :)
